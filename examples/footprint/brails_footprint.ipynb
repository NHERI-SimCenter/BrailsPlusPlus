# %% [markdown]
# # BRAILS Footprint Example
# Written by fmk

# %% [markdown]
# ## Install BRAILS++ and Plotly

# %%
# !pip install git+https://github.com/NHERI-SimCenter/BrailsPlusPlus
# !pip install plotly
# !pip install folium

# %% [markdown]
# ## Import Required Packages

# %%
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
import folium
from brails import Importer

# %% [markdown]
# ## Create a RegionBoundary for Area of Interest

# %%
LOCATION = "Tiburon, CA"

# Create an Importer instance:
importer = Importer()

# Create a region boundary:
region_boundary_class = importer.get_class('RegionBoundary')
region_boundary_object = region_boundary_class({'type': 'locationName',
                                                'data': LOCATION})

# %% [markdown]
# ## Create a Footprint Scraper and scrape the inventory
#
# options for scraper: OSM_FootprintSrcaper, USA_FootprintScraper, MS_FootprintScraper

# %%
SCRAPER = "MS_FootprintScraper"

# Scrape the building inventory from OSM:
scraper_class = importer.get_class(SCRAPER)
scraper = scraper_class({'length': 'ft'})
scraper_inventory = scraper.get_footprints(region_boundary_object)

# %% [markdown]
# ## Plot It
#
# NOTE: if using MS_FootprintScraper the fields in output are different, go back to example page and have a look at feature properties

# %%
inventory_footprints, _ = scraper_inventory.get_coordinates()

all_coords = [coord for path in inventory_footprints for coord in path]
center_lat = sum(point[1] for point in all_coords) / len(all_coords)
center_lon = sum(point[0] for point in all_coords) / len(all_coords)
m = folium.Map(location=(center_lat, center_lon), tiles="cartodbpositron", zoom_start=13)

geojson_data = scraper_inventory.get_geojson()

g = folium.GeoJson(
    geojson_data,
    name="geojson",
    tooltip=folium.GeoJsonTooltip(fields=['buildingheight','fpAreas'], sticky=False)
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_deb402dd7081507a61dbd8a3cd8e9a6c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_deb402dd7081507a61dbd8a3cd8e9a6c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_deb402dd7081507a61dbd8a3cd8e9a6c = L.map(
#                 &quot;map_deb402dd7081507a61dbd8a3cd8e9a6c&quot;,
#                 {
#                     center: [37.892648759585114, -122.47467657577779],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e6d92653688248a0a7aaf818212efdd7 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e6d92653688248a0a7aaf818212efdd7.addTo(map_deb402dd7081507a61dbd8a3cd8e9a6c);
#
#
#
#         function geo_json_3398d034baa79205ff94d47ba5979be2_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_3398d034baa79205ff94d47ba5979be2 = L.geoJson(null, {
#                 onEachFeature: geo_json_3398d034baa79205ff94d47ba5979be2_onEachFeature,
#
#         });
#
#         function geo_json_3398d034baa79205ff94d47ba5979be2_add (data) {
#             geo_json_3398d034baa79205ff94d47ba5979be2
#                 .addData(data);
#         }
#             geo_json_3398d034baa79205ff94d47ba5979be2_add({&quot;brails_version&quot;: &quot;4.0&quot;, &quot;crs&quot;: {&quot;properties&quot;: {&quot;name&quot;: &quot;urn:ogc:def:crs:OGC:1.3:CRS84&quot;}, &quot;type&quot;: &quot;name&quot;}, &quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-122.4229437889707, 37.86103368774491], [-122.4229067529638, 37.86095427675963], [-122.4228796584978, 37.86096215172036], [-122.4228506024034, 37.86089983901692], [-122.4227206908859, 37.86093760477856], [-122.4227867774025, 37.86107933150679], [-122.4229437889707, 37.86103368774491]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;buildingheight&quot;: 21.7, &quot;fpAreas&quot;: 2459, &quot;type&quot;: &quot;Building&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-122.44395984414506, 37.87693433702843], [-122.44385002128631, 37.87693751618497], [-122.4438528701176, 37.876998831084215], [-122.44382876266081, 37.87699952894725], [-122.44383112031429, 37.877050272273046], [-122.44396505062984, 37.877046395258795], [-122.44395984414506, 37.87693433702843]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;buildingheight&quot;: 41.5, &quot;fpAreas&quot;: 1426, &quot;type&quot;: &quot;Building&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-122.44516668737083, 37.87579444860782], [-122.44532366796251, 37.87590996522375], [-122.44539858237722, 37.87584652995671], [-122.44526169526314, 37.875745799362946], [-122.44526226440547, 37.87574531746571], [-122.44524217323575, 37.87573053415225], [-122.44516668737083, 37.87579444860782]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;buildingheight&quot;: 8.7, &quot;fpAreas&quot;: 1961, &quot;type&quot;: &quot;Building&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-122.45487376906088, 37.876780594054765], [-122.45497975324508, 37.87680544283992], [-122.45503319729974, 37.87666342072455], [-122.45492721311555, 37.87663857189149], [-122.45487376906088, 37.876780594054765]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;buildingheight&quot;: 14.7, &quot;fpAreas&quot;: 1724, &quot;type&quot;: &quot;Building&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-122.4446767225667, 37.87882446932569], [-122.44440075658487, 37.87893732923932], [-122.44443428144976, 37.8789883937812], [-122.44441102276411, 37.87899790699662], [-122.444439510688, 37.879041299316526], [-122.4447387208635, 37.878918917020144], [-122.4446767225667, 37.87882446932569]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;buildingheight&quot;: 17.6, &quot;fpAreas&quot;: 3615, &quot;type&quot;: &quot;Building&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&q
